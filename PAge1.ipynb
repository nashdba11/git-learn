# %% [markdown]
# <a href="https://colab.research.google.com/github/nashdba11/git-learn/blob/main/PAge1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
